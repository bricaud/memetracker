# %% [markdown]
# ## Choose a word and create a graph of n-grams from text data, then display it as a tree graph
# Looking at the neighbours of a selected word

# %% [markdown]
# ### Loading the text data

# %%
import pandas as pd
import memebox.treegraph as mtg

# %%
graph_data_path = './Data/graph/'
pickle_data_path = './Data/pickle/'
series_name = 'marseille'
series_name = 'LBDL'
pickle_file = pickle_data_path+series_name+'_texts'+'.pkl'

# %%
text_data = pd.read_pickle(pickle_file)

# %% [markdown]
# ###  Selecting documents with particular keywords

# %% [markdown]
# ## Computing the hirarchical structure

# %% [markdown]
# ### Word to search for

# %%
# with dic of ngrams
candidat_word = "secret"
candidat_word = "retrouve"
# Number n of n-grams
n_grams = 5
print('Search for the candidat word')
dic_of_ngrams = mtg.find_ngrams_dic(candidat_word,text_data,
                                                      direction='forward',n_grams=n_grams)
#nb_occur = list_of_ngram_df_merged[0].nb_occur[0]
#print('Number of occurence of \'{}\' : {}'.format(candidat_word,nb_occur))
# Out:
# Search for the candidat word

# %%
[print(s) for s in dic_of_ngrams.keys() if 'chez' in s]
# Out:
# retrouve chez
# [None]

# %%
dic_of_ngrams['retrouve chez']
# Out:
# [12981]

# %%
dic_of_ngrams
# Out:
# {'retrouve être aimé saison': [21336],
#  'retrouve davantage côté': [28890],
#  'retrouve alsace brasserie dirigée trois': [17451],
#  'retrouve magnifiquement passé trappe profit': [14425],
#  'retrouve ultime saison': [11],
#  'retrouve scénariste problèmes': [28890],
#  'retrouve position délicate trois descendantes': [28679],
#  'retrouve comédien aziz': [26961],
#  'retrouve repères': [11481],
#  'retrouve application ios android': [29389],
#  'retrouve casting premium bureau': [620],
#  'retrouve frère': [25608],
#  'retrouve celui interprété': [17784],
#  'retrouve nord': [14533],
#  'retrouve aussi systématiquement brefs flashes': [12816],
#  'retrouve mis examen bien': [20991],
#  'retrouve face reconnaît plus identité': [10679, 10680],
#  'retrouve bureau': [234, 3336, 11918],
#  'retrouve grand': [11213],
#  'retrouve doté vitesse extraordinaire': [13841],
#  'retrouve leurs': [223, 224, 225, 227, 230, 395],
#  'retrouve part lion car monde': [14425],
#  'retrouve face reconnaît': [10679, 10680],
#  'retrouve cinéma explore nouveau monde': [492, 512],
#  'retrouve centre attention': [13841],
#  'retrouve terrain': [3018, 3099, 3100, 16904],
#  'retrouve interventions compte twitter house': [21546],
#  'retrouve semaine': [29363],
#  'retrouve ici approche très proche': [6383],
#  'retrouve affaire bien': [19721],
#  'retrouve envoyée france comme': [17523, 17531],
#  'retrouve importance savoir': [28679],
#  'retrouve fille': [638, 638, 2831, 2833, 8946, 29198],
#  'retrouve enquêter enlèvement': [27845],
#  'retrouve soleil dedans disque chansons': [2389, 2694],
#  'retrouve jean pierre daroussin': [2612],
#  'retrouve également cinéma': [9820],
#  'retrouve scorpion': [11124],
#  'retrouve frère première bande': [25608],
#  'retrouve traqué police': [13788],
#  'retrouve davantage cinéma': [10489],
#  'retrouve seul cadavre': [13325, 13325],
#  'retrouve pays origine australia': [492, 512],
#  'retrouve expliquer': [13693],
#  'retrouve autres séries': [12663],
#  'retrouve face': [1516, 10679, 10680],
#  'retrouve plus tard espions': [17451],
#  'retrouve marilou sarah mehdi': [14774],
#  'retrouve également jean': [13135],
#  'retrouve réalisateur original': [25811],
#  'retrouve centre attention médias secrets': [13841],
#  'retrouve histoire clans fois vrais': [8335],
#  'retrouve coincée': [28715, 29164],
#  'retrouve hugh jackman': [20922, 20923],
#  'retrouve ensuite': [6272,
#   6274,
#   6964,
#   9343,
#   9354,
#   9503,
#   9504,
#   9505,
#   9507,
#   10433,
#   14168],
#  'retrouve iran infiltrer milieu': [29345, 29351],
#  'retrouve encore fois': [20655, 20731],
#  'retrouve plus': [11001, 13841, 17451],
#  'retrouve devant image ultra éclairée': [16327],
#  'retrouve paga': [5806],
#  'retrouve téhéran entourage': [17356],
#  'retrouve 2014 illustre': [668],
#  'retrouve foyer jeunes': [14166],
#  'retrouve complice michel fau': [12893],
#  'retrouve réfugier laborieusement derrière': [14425],
#  'retrouve coeur exactions': [22025],
#  'retrouve perdu incompréhension disparition': [28334],
#  'retrouve coincée accueil aime cambouis': [28715, 29164],
#  'retrouve cinéma explore nouveau': [492, 512],
#  'retrouve griffes': [16420, 16421],
#  'retrouve quand malice coin oeil': [11496],
#  'retrouve scorpion autre': [11124],
#  'retrouve mis examen bien troublé': [20991],
#  'retrouve jean': [2612, 17364, 19656, 21963, 22715],
#  'retrouve mathilde': [17364],
#  'retrouve thème coeur première': [27528],
#  'retrouve partie travers célèbre': [13304],
#  'retrouve étouffée': [9941],
#  'retrouve également louise bourgoin lambert': [27854],
#  'retrouve intrusion étouffant plupart temps': [10835],
#  'retrouve donc certains': [14430, 14431],
#  'retrouve série très important': [17781],
#  'retrouve désir sonner juste': [28091],
#  'retrouve traqué': [13788],
#  'retrouve rappeurs duo rizzle kicks': [6635],
#  'retrouve aussi réussite série export': [17290, 17304, 17305],
#  'retrouve line renaud nathalie baye': [14320],
#  'retrouve repères corrado grâce autres': [11481],
#  'retrouve parachuté cuisine sans': [13923],
#  'retrouve ncis nouvelle orléans': [11140],
#  'retrouve charge petite fille': [29198],
#  'retrouve habillé': [14232],
#  'retrouve bien codes genre ils': [14435],
#  'retrouve effet réalisation pilote': [0],
#  'retrouve scorpion autre nouveauté': [11124],
#  'retrouve bien codes genre': [14435],
#  'retrouve final avoir réactions incohérentes': [10791],
#  'retrouve assassinée chambre hôtel décide': [16327],
#  'retrouve série adoubée critique': [12036],
#  'retrouve bande': [8812, 8815, 8817, 8818, 8827, 8828, 8830, 8835, 8839],
#  'retrouve grand mathieu héros très': [11213],
#  'retrouve terrain prédilection': [3018, 3099, 3100],
#  'retrouve dernier homme vivant terre': [25],
#  'retrouve jamais soupçonné': [27635],
#  'retrouve six troupes': [9820],
#  'retrouve nombreuses mai 2016 cellule': [16865],
#  'retrouve droits sériephile évidemment': [29188],
#  'retrouve compère that 70s show': [12463],
#  'retrouve piégé agiter': [27157],
#  'retrouve partir': [16324],
#  'retrouve monde espionnage après': [9941],
#  'retrouve peu problème': [8084],
#  'retrouve moyen': [17054],
#  'retrouve alsace': [17451],
#  'retrouve iran infiltrer milieu nucléaire': [29345, 29351],
#  'retrouve embouteillages commencé': [15671],
#  'retrouve france': [2265, 2384, 2476],
#  'retrouve ici codes série américaine': [13986],
#  'retrouve finalement côtés': [14558],
#  'retrouve alors embarqué histoire': [12583],
#  'retrouve téhéran entourage famille': [17356],
#  'retrouve bord gouffre énigmes': [28334],
#  'retrouve boucle histoire cet homme': [16267, 16268, 17794],
#  'retrouve 4ème': [2902],
#  'retrouve tranquillou bientôt fin après': [14425],
#  'retrouve également camille': [16911],
#  'retrouve maison richard': [13826],
#  'retrouve patte permet différencier': [12663],
#  'retrouve part': [14425],
#  'retrouve mediapart': [6449, 9562],
#  'retrouve côté vieux': [4351],
#  'retrouve rentrée émission': [26856],
#  'retrouve final avoir réactions': [10791],
#  'retrouve également côté sélection monde': [2430],
#  'retrouve autres shantel vansanten': [11496],
#  'retrouve boucle': [16267, 16268, 17794],
#  'retrouve maison richard bernadette weekend': [13826],
#  'retrouve motifs': [2430],
#  'retrouve thème coeur première série': [27528],
#  'retrouve exemple': [12034],
#  'retrouve marc': [187],
#  'retrouve blooklyn comment relever changement': [12816],
#  'retrouve faire captation documentaire': [16057],
#  'retrouve opéra rend compte': [10700, 10774],
#  'retrouve épisodes deviousmaids peux': [23661],
#  'retrouve situation compliquée marina loiseau': [20033],
#  'retrouve bord gouffre énigmes faudra': [28334],
#  'retrouve aime': [7804],
#  'retrouve confrontée': [7075, 11146],
#  'retrouve légende': [16973, 16974],
#  'retrouve variation registres cinéma': [14068, 14070],
#  'retrouve chroniqueurs': [16216],
#  'retrouve foyer jeunes adolescentes difficiles': [14166],
#  'retrouve saul goodman': [12819],
#  'retrouve légende saison': [16973, 16974],
#  'retrouve film espionne sans': [12745],
#  'retrouve comédien aziz ansari découvert': [26961],
#  'retrouve alsace brasserie dirigée': [17451],
#  'retrouve terrain prédilection histoires': [3018, 3099, 3100],
#  'retrouve importance savoir recevoir': [28679],
#  'retrouve phénomène': [8973],
#  'retrouve terrain syrie': [16904],
#  'retrouve moins autant texte images': [13810],
#  'retrouve phénomène addiction': [8973],
#  'retrouve vite plongé nouvelles': [11062],
#  'retrouve expliquer non': [13693],
#  'retrouve faire': [16057],
#  'retrouve 4ème position meilleures': [2902],
#  'retrouve autres shantel': [11496],
#  'retrouve dawgz actualité site réseaux': [7630],
#  'retrouve idole': [10179],
#  'retrouve souvent poche manteau': [25881],
#  'retrouve american crime': [7929],
#  'retrouve rapidement forcé collaborer ennemi': [6022],
#  'retrouve vraie vie paris après': [1027,
#   1031,
#   2660,
#   2670,
#   2725,
#   3152,
#   3288,
#   3439],
#  'retrouve film notamment': [14249],
#  'retrouve peau autre situation vertigineuse': [10016],
#  'retrouve cet élan': [29238],
#  'retrouve leurs traces web quoi': [223, 224, 225, 227, 230, 395],
#  'retrouve tommy convaincre quand': [26569],
#  'retrouve rupture': [1780],
#  'retrouve perdue': [11496],
#  'retrouve bien sûr malotru': [17301, 17302, 17357],
#  'retrouve sans livres': [29208],
#  'retrouve plongé': [14461, 14461, 14463, 14463],
#  'retrouve revenants six mois': [13830],
#  'retrouve partir mai pourquoi accepté': [16324],
#  'retrouve repères corrado': [11481],
#  'retrouve enfin plupart acteurs': [20655, 20731],
#  'retrouve jean pierre': [2612],
#  'retrouve décors reconstitution convaincante bureaux': [17685],
#  'retrouve donc bureau': [16858],
#  'retrouve amis': [12873, 13826],
#  'retrouve scénaristes wood': [417],
#  'retrouve pouvoir': [14533],
#  'retrouve menus présente bien établissement': [448],
#  'retrouve plus tard espions dgse': [17451],
#  'retrouve vraie vie': [1027, 1031, 2660, 2670, 2725, 3152, 3288, 3439],
#  'retrouve mission top': [7937, 7940, 7941, 7942, 7944, 7946],
#  'retrouve interventions compte': [21546],
#  'retrouve ici approche très': [6383],
#  'retrouve sous texte inintéressant': [14425],
#  'retrouve situation compliquée marina': [20033],
#  'retrouve plus tard': [17451],
#  'retrouve très': [15223, 17781],
#  'retrouve notamment marina': [27510, 27528],
#  'retrouve jason isaacs': [14533],
#  'retrouve moins autant': [13810],
#  'retrouve suits 21e': [13362],
#  'retrouve ici hôpital': [12583],
#  'retrouve coeur exactions sanglantes': [22025],
#  'retrouve grand mathieu héros': [11213],
#  'retrouve peu': [5831, 8084, 29213],
#  'retrouve certes encore': [10451],
#  'retrouve inimitable': [2543, 2544, 2576],
#  'retrouve fille collègues': [2831, 2833],
#  'retrouve long série derrière ordinateur': [1808],
#  'retrouve ncis nouvelle orléans dernier': [11140],
#  'retrouve nouveauté wgn america': [12036],
#  'retrouve compère': [12463],
#  'retrouve davantage cinéma télé': [10489],
#  'retrouve piégé agiter tenter': [27157],
#  'retrouve intensité spy game zero': [13265],
#  'retrouve viseur': [17451, 29269],
#  'retrouve alsace brasserie': [17451],
#  'retrouve josh': [14533],
#  'retrouve bureau légendes pilote': [3336],
#  'retrouve application ios': [29389],
#  'retrouve variation': [14068, 14070],
#  'retrouve écran rend': [10790, 12704],
#  'retrouve affaire bien trop grande': [19721],
#  'retrouve prises jumeau décédé face': [10689, 10690, 10694],
#  'retrouve ici approche': [6383],
#  'retrouve nombreuses mai': [16865],
#  'retrouve parfum sulfureux série': [13346, 13348],
#  'retrouve bien ancrées vie': [25214],
#  'retrouve confrontée monde': [7075],
#  'retrouve american': [7929],
#  'retrouve shameless série chouchoute': [12036],
#  'retrouve ainsi plusieurs': [13656],
#  'retrouve 2014 illustre inconnu matthieu': [668],
#  'retrouve beaucoup tables': [4729],
#  'retrouve famille reprend marques': [16327],
#  'retrouve côté vieux continent': [4351],
#  'retrouve final': [10791],
#  'retrouve envahie russie': [6022],
#  'retrouve 2014 illustre inconnu': [668],
#  'retrouve presse saurai donc vient': [18101],
#  'retrouve confronté choix cornéliens': [17116],
#  'retrouve méchants': [14435],
#  'retrouve aussi commune vraiment': [14155],
#  'retrouve sous': [14425],
#  'retrouve tf1 soirée exceptionnelle': [16493],
#  'retrouve force cet': [13986],
#  'retrouve slogan': [37, 38],
#  'retrouve réfugier laborieusement': [14425],
#  'retrouve intensité spy': [13265],
#  'retrouve aussi décors bureau': [8084],
#  'retrouve aussi ecoutes nsa guerre': [19546, 19547, 19554, 19564, 21470],
#  'retrouve casting série italienne': [28910],
#  'retrouve oréal danone bonduelle': [27360, 27361, 27389, 27468],
#  'retrouve ainsi plusieurs personnages issus': [13656],
#  'retrouve thématiques familières hantises nipponnes': [8491],
#  'retrouve envahie russie réserves pétrole': [6022],
#  'retrouve ainsi talent patriotes': [27726],
#  'retrouve dénominateurs communs': [8946],
#  'retrouve rentrée émission horaire': [26856],
#  'retrouve côté sérial très': [28368],
#  'retrouve très bien': [17781],
#  'retrouve pouvoir réalisé simon cella': [14533],
#  'retrouve nouveauté': [12036],
#  'retrouve part lion': [14425],
#  'retrouve autres': [2544, 9204, 11496, 12663],
#  'retrouve plusieurs séries': [12036],
#  'retrouve confrontée frontière pensait': [11146],
#  'retrouve nombreuses mai 2016': [16865],
#  'retrouve faut redresse barre': [15543],
#  'retrouve sous texte': [14425],
#  'retrouve enfin mathieu kassovitz': [14462],
#  'retrouve vie': [1780, 2866, 2867, 2926, 4724, 5324, 5659, 9336, 10128],
#  'retrouve suivi sens danger': [8946],
#  'retrouve série adoubée': [12036],
#  'retrouve fille danger choses autant': [8946],
#  'retrouve the newsroom': [12036],
#  'retrouve finalement': [13923, 14558],
#  'retrouve amiel devenu': [10791],
#  'retrouve tête série matthieu kassovitz': [5831],
#  'retrouve aussi décors bureau minority': [8084],
#  'retrouve sept épisodes': [12036],
#  'retrouve emma caunes tournage': [24155, 24272],
#  'retrouve soir avant première saison': [16160],
#  'retrouve intensité': [13265],
#  'retrouve maison': [13826],
#  'retrouve hippocampus studio baguette': [9039],
#  'retrouve @mediapart agent': [12884],
#  'retrouve faut savoir': [10957],
#  'retrouve opéra rend compte sosie': [10700, 10774],
#  'retrouve revenants': [13830],
#  'retrouve ensuite @mediapart dialogue': [9343, 9354],
#  'retrouve expliquer non vais': [13693],
#  'retrouve aussi grand plaisir': [13088],
#  'retrouve perdue milieu nulle part': [11496],
#  'retrouve long série': [1808],
#  'retrouve piégé agiter tenter sortir': [27157],
#  'retrouve rappeurs duo rizzle': [6635],
#  'retrouve certes encore fois': [10451],
#  'retrouve être': [21336],
#  'retrouve coincée accueil aime': [28715, 29164],
#  'retrouve fille danger': [8946],
#  'retrouve réalisateur': [25811],
#  'retrouve marilou': [14774],
#  'retrouve alors': [12583, 12926],
#  'retrouve coeur sombre machination': [3241],
#  'retrouve celui interprété mathieu': [17784],
#  'retrouve immédiatement': [6795],
#  'retrouve @mediapart prévenait': [12364, 12367],
#  'retrouve également': [2430, 9820, 13135, 13923, 16911, 27854],
#  'retrouve ici codes série': [13986],
#  'retrouve interventions compte twitter': [21546],
#  'retrouve the affair remporté golden': [12036],
#  'retrouve beaucoup scènes': [20655, 20731],
#  'retrouve fille problème': [638],
#  'retrouve mathieu kassovitz rôle guillaume': [17492],
#  'retrouve aussi réussite série': [17290, 17304, 17305],
#  'retrouve griffes armée': [16420, 16421],
#  'retrouve talent patriotes': [14588],
#  'retrouve intensité spy game': [13265],
#  'retrouve dawgz actualité': [7630],
#  'retrouve mêmes têtes': [27253],
#  'retrouve dernier homme': [25],
#  'retrouve embarqué ennuis police lesquels': [14435],
#  'retrouve parachuté cuisine': [13923],
#  'retrouve quasi totalité épisodes': [12812, 29267],
#  'retrouve femme': [3151,
#   3153,
#   3178,
#   3344,
#   3363,
#   3583,
#   3903,
#   4734,
#   4735,
#   4736,
#   4737,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4743,
#   4744,
#   4745,
#   4746,
#   5251,
#   5292,
#   5303,
#   5399,
#   5455,
#   5474,
#   5514,
#   5701,
#   5702,
#   5703,
#   5704,
#   5705,
#   5706,
#   5707,
#   5708,
#   5709,
#   5710,
#   5711,
#   5712,
#   5713,
#   5724,
#   5755,
#   5784,
#   5814,
#   5821,
#   5839,
#   5848,
#   5883,
#   5884,
#   5888,
#   5896,
#   5972,
#   5982,
#   5983,
#   5984,
#   5985,
#   5986,
#   5987,
#   5988,
#   5989,
#   5990,
#   5991,
#   5992,
#   5993,
#   5994,
#   6044],
#  'retrouve vite': [10791, 11062, 12687],
#  'retrouve doté': [13841],
#  'retrouve chroniqueurs patrice carmouze eric': [16216],
#  'retrouve marina loiseau': [19070, 19422, 19720],
#  'retrouve pouvoir réalisé': [14533],
#  'retrouve infirmière stagiaire': [961],
#  'retrouve effet': [0],
#  'retrouve troubles géo': [29165],
#  'retrouve tf1': [16493, 26847],
#  'retrouve également jean pierre': [13135],
#  'retrouve prises jumeau': [10689, 10690, 10694],
#  'retrouve vie parisienne': [2866, 2867, 2926, 4724, 5324, 5659, 9336, 10128],
#  'retrouve certes encore fois centre': [10451],
#  'retrouve semaine affiche': [29363],
#  'retrouve leurs traces web': [223, 224, 225, 227, 230, 395],
#  'retrouve composer': [12501],
#  'retrouve sous texte inintéressant fond': [14425],
#  'retrouve thèmes spécialiste': [1780],
#  'retrouve aussi bien': [12428],
#  'retrouve devant image': [16327],
#  'retrouve canal hbo grandi univers': [2544],
#  'retrouve gillian anderson': [14671],
#  'retrouve sept épisodes finaux': [12036],
#  'retrouve fille collègues bureau': [2831, 2833],
#  'retrouve 2001 michael crocodile': [8520],
#  'retrouve infirmière': [961],
#  'retrouve position': [28679],
#  'retrouve envoyée france': [17523, 17531],
#  'retrouve patte': [12663],
#  'retrouve tenir country': [1780],
#  'retrouve grosse équipe deux': [16057],
#  'retrouve léa drucker balmès': [19529],
#  'retrouve leurs traces': [223, 224, 225, 227, 230, 395],
#  'retrouve fille lydia': [29198],
#  'retrouve habillé plage naturiste vécu': [14232],
#  'retrouve moins autant texte': [13810],
#  'retrouve nord tis': [14533],
#  'retrouve série adoubée critique spécialisée': [12036],
#  'retrouve grand mathieu': [11213],
#  'retrouve amiel devenu très proche': [10791],
#  'retrouve flop': [12894],
#  'retrouve rappeurs': [6635],
#  'retrouve hippocampus': [9039],
#  'retrouve séries deutschland': [2891, 3000, 14426],
#  'retrouve côté vieux continent moins': [4351],
#  'retrouve infiltration genre film': [13656],
#  'retrouve réalisateur original effet': [25811],
#  'retrouve donc derrière': [13656],
#  'retrouve intrusion': [10835],
#  'retrouve vite désamorcé': [12687],
#  'retrouve certains échos particulier rude': [23876, 23877],
#  'retrouve très vite limitée': [15223],
#  'retrouve beaucoup tables monde notamment': [4729],
#  'retrouve décors reconstitution': [17685],
#  'retrouve autres films': [9204],
#  'retrouve amaury': [13157],
#  'retrouve donc notamment cinéma': [16806, 16898],
#  'retrouve donc certains adages': [14430, 14431],
#  'retrouve tête série matthieu': [5831],
#  'retrouve scénariste': [28890],
#  'retrouve niveau': [13296],
#  'retrouve charge': [29198],
#  'retrouve équipe bureau légendes': [17185, 17297],
#  'retrouve affaire bien trop': [19721],
#  'retrouve côté': [4351, 11124, 28368],
#  'retrouve enquêter enlèvement lié passé': [27845],
#  'retrouve embarqué ennuis': [14435],
#  'retrouve série joe weisberg': [26569],
#  'retrouve saison hard canal': [11481],
#  'retrouve france ancienne maîtresse nadia': [2265, 2384, 2476],
#  'retrouve tête série': [5831],
#  'retrouve autres mathieu kassovitz léa': [2544],
#  'retrouve devant image ultra': [16327],
#  'retrouve prison avoir sciemment': [186],
#  'retrouve poste': [11727, 11728, 11730],
#  'retrouve épisodes deviousmaids': [23661],
#  'retrouve certains échos': [23876, 23877],
#  'retrouve ventre mou épisodes rythme': [14339],
#  'retrouve terrain syrie liban irak': [16904],
#  'retrouve chronique oeil carlito': [17364],
#  'retrouve derrière arte': [13824],
#  'retrouve infiltration ambiance': [13656],
#  'retrouve mission top secrète paris': [7937, 7940, 7941, 7942, 7944, 7946],
#  'retrouve unbreakable kimmy': [12036],
#  'retrouve mathieu': [3874, 17492],
#  'retrouve série': [12036, 17781, 26569],
#  'retrouve 2014': [668],
#  'retrouve talent patriotes échec mobiusu': [14588],
#  'retrouve mêmes têtes chaque': [27253],
#  'retrouve place': [915, 916],
#  'retrouve jean marc morandini nrj': [17364, 19656, 21963, 22715],
#  'retrouve blida': [2770],
#  'retrouve fantastique relecture passionnante inventive': [13216,
#   13227,
#   13402],
#  'retrouve tf1 soirée exceptionnelle faudra': [16493],
#  'retrouve tenir country club gratin': [1780],
#  'retrouve fraîcheur programme balade': [20570],
#  'retrouve plaisir ambiance également': [11496],
#  'retrouve également photo': [13923],
#  'retrouve donc jane': [11496],
#  'retrouve alors service': [12926],
#  'retrouve ensuite @mediapart dialogue #bureaudeslégendes': [9343, 9354],
#  'retrouve énormément romans': [8946],
#  'retrouve aussi réussite': [17290, 17304, 17305],
#  'retrouve moins': [13810],
#  'retrouve peu atmosphère patriotes éric': [29213],
#  'retrouve amis quelques': [13826],
#  'retrouve méchants typiques genre': [14435],
#  'retrouve autres films cousin': [9204],
#  'retrouve faire captation': [16057],
#  'retrouve netflix': [27567, 27568],
#  'retrouve beaucoup tables monde': [4729],
#  'retrouve cet élan oblige aujourd': [29238],
#  'retrouve force cet écrivain': [13986],
#  'retrouve mêmes personnages joués mathieu': [17622],
#  'retrouve perdu': [28334],
#  'retrouve envahie russie réserves': [6022],
#  'retrouve film notamment personnages': [14249],
#  'retrouve inimitable mathieu': [2543, 2544, 2576],
#  'retrouve silvio dante pays saut': [12663],
#  'retrouve pays autre peut': [12562],
#  'retrouve silvio dante': [12663],
#  'retrouve ici univers': [10431, 10433, 10437, 10437],
#  'retrouve mission top secrète': [7937, 7940, 7941, 7942, 7944, 7946],
#  'retrouve noms irène jacob': [15095],
#  'retrouve rapidement': [6022],
#  'retrouve faut redresse': [15543],
#  'retrouve quelques partenaires jeu': [12926],
#  'retrouve donc situation hors zones': [13199],
#  'retrouve toujours': [6228],
#  'retrouve tf1 esprits criminels série': [26847],
#  'retrouve peau autre': [10016],
#  'retrouve josh holloway lost disparus': [14533],
#  'retrouve hugh jackman rila': [20922, 20923],
#  'retrouve fois réalisation': [5288, 5308, 5346, 5426],
#  'retrouve agent secret tourné': [14068, 14070],
#  'retrouve également cinéma cœur hommes': [9820],
#  'retrouve mathilde seigner': [17364],
#  'retrouve thématiques familières hantises': [8491],
#  'retrouve foyer jeunes adolescentes': [14166],
#  'retrouve scénaristes': [417],
#  'retrouve finalement petit outre': [13923],
#  'retrouve american crime questionnements sillonnent': [7929],
#  'retrouve 2016': [14522],
#  'retrouve davantage': [10489, 28890],
#  'retrouve variation registres': [14068, 14070],
#  'retrouve série joe weisberg joe': [26569],
#  'retrouve ici': [6383, 10431, 10433, 10437, 10437, 12583, 13986],
#  'retrouve thème coeur': [27528],
#  'retrouve bureau légendes tension': [11918],
#  'retrouve ncis': [11140],
#  'retrouve the': [12036, 12036],
#  'retrouve confrontée frontière pensait jamais': [11146],
#  'retrouve marilou sarah': [14774],
#  'retrouve notamment marina envoyée première': [27510, 27528],
#  'retrouve également photo ancien policier': [13923],
#  'retrouve très bien série propos': [17781],
#  'retrouve prune': [8768, 11176, 27764],
#  'retrouve viseur bdl parce': [29269],
#  'retrouve coeur sombre': [3241],
#  'retrouve première': [9820],
#  'retrouve partie travers': [13304],
#  'retrouve tranquillou bientôt': [14425],
#  'retrouve ainsi': [13656, 27726],
#  'retrouve bien sûr': [17301, 17302, 17357],
#  'retrouve film espionne': [12745],
#  'retrouve seul cadavre assaillants fois': [13325, 13325],
#  'retrouve france ancienne maîtresse': [2265, 2384, 2476],
#  'retrouve blida dès lundi': [2770],
#  'retrouve ici hôpital ambiance angoissante': [12583],
#  'retrouve faut savoir cela': [10957],
#  'retrouve film notamment personnages toujours': [14249],
#  'retrouve infiltration ambiance particulièrement': [13656],
#  'retrouve femme planches 15h20france diffuser': [3151,
#   3153,
#   3178,
#   3344,
#   3363,
#   3583,
#   3903],
#  'retrouve mediapart réplique culte': [9562],
#  'retrouve situation impossible': [16952],
#  'retrouve emma': [24155, 24272],
#  'retrouve évidemment': [119],
#  'retrouve suits 21e penny': [13362],
#  'retrouve presse saurai donc': [18101],
#  'retrouve canal hbo grandi': [2544],
#  'retrouve aussi commune vraiment plaisir': [14155],
#  'retrouve alexandra': [13986],
#  'retrouve étouffée surplus dialogues': [9941],
#  'retrouve monde espionnage': [9941],
#  'retrouve mediapart réplique': [9562],
#  'retrouve agent secret tourné ridicule': [14068, 14070],
#  'retrouve encore fois marie': [20655, 20731],
#  'retrouve aime cinéma': [7804],
#  'retrouve flop stalker annulée': [12894],
#  'retrouve jean marc': [17364, 19656, 21963, 22715],
#  'retrouve couple principal aussi deux': [26081],
#  'retrouve emma caunes': [24155, 24272],
#  'retrouve vite être prisonnier mal': [10791],
#  'retrouve sans faute débat mené': [1265],
#  'retrouve infiltration genre film espionnage': [13656],
#  'retrouve devant vraie réflexion': [5298],
#  'retrouve rentrée': [26856],
#  'retrouve iran infiltrer': [29345, 29351],
#  'retrouve poste bureau': [11727, 11728, 11730],
#  'retrouve motifs identité espion forme': [2430],
#  'retrouve sphère': [17479],
#  'retrouve opéra': [10700, 10774],
#  'retrouve comédien aziz ansari': [26961],
#  'retrouve léa': [19529],
#  'retrouve presse': [18101],
#  'retrouve semaine affiche cancre paul': [29363],
#  'retrouve effet réalisation pilote scorpion': [0],
#  'retrouve saison hard': [11481],
#  'retrouve celui': [17784],
#  'retrouve tf1 soirée': [16493],
#  'retrouve côté témoins france aequo': [11124],
#  'retrouve aussi bien oeuvres jeunes': [12428],
#  'retrouve devant vraie réflexion moralité': [5298],
#  'retrouve fille lydia erin': [29198],
#  'retrouve trois series finales': [12036],
#  'retrouve 2001 michael crocodile dundee': [8520],
#  'retrouve certains codes': [29365],
#  'retrouve ventre': [14339],
#  'retrouve aussi bien oeuvres': [12428],
#  'retrouve alors embarqué': [12583],
#  'retrouve agent secret': [14068, 14070],
#  'retrouve savoir plus allociné': [18314],
#  'retrouve josh holloway lost': [14533],
#  'retrouve quasi': [12812, 29267],
#  'retrouve pays autre peut observer': [12562],
#  'retrouve beaucoup': [4729, 20655, 20731],
#  'retrouve cet': [29238],
#  'retrouve davantage côté comédie': [28890],
#  'retrouve vite être prisonnier': [10791],
#  'retrouve parmi elles spotless lire': [212],
#  'retrouve variation registres cinéma américain': [14068, 14070],
#  'retrouve savoir plus allociné rendu': [18314],
#  'retrouve dernier homme vivant': [25],
#  'retrouve suits 21e penny dreadful': [13362],
#  'retrouve fibre film patriotes dédaignant': [3179, 5430, 5430],
#  'retrouve ensuite mediapart mag': [10433],
#  'retrouve notamment felicity': [25],
#  'retrouve pays origine australia spuper': [492, 512],
#  'retrouve donc bureau légendes': [16858],
#  'retrouve plus souvent commentaires pilot': [13841],
#  'retrouve position délicate trois': [28679],
#  'retrouve magnifiquement passé': [14425],
#  'retrouve lire meilleur film français': [16805, 29263],
#  'retrouve peu atmosphère patriotes': [29213],
#  'retrouve lendemain': [12796],
#  'retrouve plaisir autre': [8917, 8954, 29303],
#  'retrouve plusieurs séries visent public': [12036],
#  'retrouve trois series': [12036],
#  'retrouve film espionne sans susciter': [12745],
#  'retrouve ensuite mediapart #bureaudeslegendes': [6964],
#  'retrouve lire meilleur film': [16805, 29263],
#  'retrouve composer recoller morceaux comble': [12501],
#  'retrouve plus souvent commentaires': [13841],
#  'retrouve situation impossible quand': [16952],
#  'retrouve gillian anderson incarner': [14671],
#  'retrouve cinéma': [492, 512],
#  'retrouve fille _________________ océans': [638],
#  'retrouve dawgz actualité site': [7630],
#  'retrouve sphère familiale': [17479],
#  'retrouve menus présente': [448],
#  'retrouve énormément romans john carré': [8946],
#  'retrouve grosse': [16057],
#  'retrouve lire': [16805, 29263],
#  'retrouve lire meilleur': [16805, 29263],
#  'retrouve donc plein années esthétique': [11496],
#  'retrouve quotidien parisien bureau': [5070],
#  'retrouve peau autre situation': [10016],
#  'retrouve bureau légendes': [234, 3336, 11918],
#  'retrouve 4ème position': [2902],
#  'retrouve perdu incompréhension disparition trop': [28334],
#  'retrouve histoire clans': [8335],
#  'retrouve idole roy poutre': [10179],
#  'retrouve donc': [11496,
#   11496,
#   13199,
#   13656,
#   14430,
#   14431,
#   16420,
#   16421,
#   16424,
#   16806,
#   16858,
#   16898],
#  'retrouve centre': [13841],
#  'retrouve line': [14320],
#  'retrouve mêmes': [17622, 27253],
#  'retrouve talent': [14588],
#  'retrouve motifs identité': [2430],
#  'retrouve trois series finales œuvres': [12036],
#  'retrouve rappeurs duo': [6635],
#  'retrouve position délicate': [28679],
#  'retrouve inimitable mathieu kassovitz rôle': [2543, 2544, 2576],
#  'retrouve fois': [5288, 5308, 5346, 5426],
#  'retrouve fibre film': [3179, 5430, 5430],
#  'retrouve mise': [10794],
#  'retrouve être aimé saison beaucoup': [21336],
#  'retrouve quotidien': [5070],
#  'retrouve face deux problématiques renouveler': [1516],
#  'retrouve confrontée monde rural': [7075],
#  'retrouve compère that 70s': [12463],
#  'retrouve histoire littérature': [14070],
#  'retrouve première marche top': [9820],
#  'retrouve paris': [29373],
#  'retrouve également côté': [2430],
#  'retrouve mêmes personnages': [17622],
#  'retrouve marina': [19070, 19422, 19720],
#  'retrouve également camille cottin': [16911],
#  'retrouve jason isaacs star wars': [14533],
#  'retrouve soir avant première': [16160],
#  'retrouve casting': [620, 28910],
#  'retrouve viseur mystérieux': [17451],
#  'retrouve complice michel fau plaisir': [12893],
#  'retrouve doté vitesse extraordinaire après': [13841],
#  'retrouve moyen âge châteaux cathares': [17054],
#  'retrouve ventre mou épisodes': [14339],
#  'retrouve patte permet différencier dommage': [12663],
#  'retrouve parmi elles spotless lancée': [211],
#  'retrouve shameless série chouchoute communauté': [12036],
#  'retrouve séries deutschland vie devant': [2891, 3000, 14426],
#  'retrouve chronique adolescente intelligente fois': [15277],
#  'retrouve chaque show plaisir non': [27742,
#   27743,
#   27744,
#   27745,
#   27746,
#   27747,
#   27751,
#   27752,
#   27753,
#   27754,
#   27755,
#   27756,
#   27757,
#   27758,
#   27759,
#   27775,
#   27776,
#   27778,
#   27781,
#   27782,
#   27783,
#   27784,
#   28187],
#  'retrouve murs': [26921],
#  'retrouve enfin': [14462, 20655, 20731],
#  'retrouve rupture chaises': [1780],
#  'retrouve nathalieandref2 semaine': [22457],
#  'retrouve confronté': [17116],
#  'retrouve table premier': [19327],
#  'retrouve très bien série': [17781],
#  'retrouve magnifiquement passé trappe': [14425],
#  'retrouve pourchassé place après': [880, 893, 899],
#  'retrouve patte permet': [12663],
#  'retrouve chaque': [27742,
#   27743,
#   27744,
#   27745,
#   27746,
#   27747,
#   27751,
#   27752,
#   27753,
#   27754,
#   27755,
#   27756,
#   27757,
#   27758,
#   27759,
#   27775,
#   27776,
#   27778,
#   27781,
#   27782,
#   27783,
#   27784,
#   28187],
#  'retrouve griffes armée syrienne': [16420, 16421],
#  'retrouve suivi': [8946],
#  'retrouve saison hard canal rôle': [11481],
#  'retrouve donc certains adages canal': [14430, 14431],
#  'retrouve @mediapart agent #fsb': [12884],
#  'retrouve fois réalisation série': [5288, 5308, 5346, 5426],
#  'retrouve prochain fond': [14522],
#  'retrouve shameless série': [12036],
#  'retrouve peu atmosphère': [29213],
#  'retrouve légende saison sait': [16973, 16974],
#  'retrouve tommy': [26569],
#  'retrouve autres films cousin bob': [9204],
#  'retrouve sans livres vinyles': [29208],
#  'retrouve jean pierre daroussin léa': [2612],
#  'retrouve interventions': [21546],
#  'retrouve finalement petit outre marseille': [13923],
#  'retrouve mis': [20991],
#  'retrouve peu problème acteurs': [8084],
#  'retrouve ventre mou': [14339],
#  'retrouve faut savoir cela home': [10957],
#  'retrouve pourchassé place après moults': [880, 893, 899],
#  'retrouve infirmière stagiaire ans sous': [961],
#  'retrouve moyen âge châteaux': [17054],
#  'retrouve murs insurrection populaire pays': [26921],
#  'retrouve opéra rend': [10700, 10774],
#  'retrouve pourchassé place': [880, 893, 899],
#  'retrouve histoire littérature genre source': [14070],
#  'retrouve fille problème fille comprend': [638],
#  'retrouve françois david jonathan': [11496],
#  'retrouve meera ruhit': [11496],
#  'retrouve saul goodman plutôt': [12819],
#  'retrouve première marche top grâce': [9820],
#  'retrouve nathalieandref2 semaine prochaine infosportplus': [22457],
#  'retrouve couple': [26081],
#  'retrouve ici univers narratif': [10431, 10433, 10437, 10437],
#  'retrouve habillé plage naturiste': [14232],
#  'retrouve fraîcheur': [19905, 20570],
#  'retrouve côté témoins': [11124],
#  'retrouve sans faute': [1265],
#  'retrouve rentrée émission horaire sait': [26856],
#  'retrouve quarante ans': [17116],
#  'retrouve casting série': [28910],
#  'retrouve plongé arène judiciaire': [14461, 14461, 14463, 14463],
#  'retrouve quotidien parisien bureau légendes': [5070],
#  'retrouve réfugier': [14425],
#  'retrouve plusieurs': [12036],
#  'retrouve jamais': [27635],
#  'retrouve vite plongé': [11062],
#  'retrouve donc situation': [13199],
#  'retrouve tenir country club': [1780],
#  'retrouve décors reconstitution convaincante': [17685],
#  'retrouve fantastique relecture passionnante': [13216, 13227, 13402],
#  'retrouve derrière arte tmc nrj12': [13824],
#  'retrouve bureau légendes pilote clandestins': [3336],
#  'retrouve monde': [9941],
#  'retrouve propulsée 2012': [536],
#  'retrouve maison richard bernadette': [13826],
#  'retrouve également jean pierre darroussin': [13135],
#  'retrouve droits sériephile': [29188],
#  'retrouve étouffée surplus': [9941],
#  'retrouve six troupes venant': [9820],
#  'retrouve the newsroom pourrait être': [12036],
#  'retrouve ici codes': [13986],
#  'retrouve blida dès': [2770],
#  'retrouve viseur mystérieux groupe': [17451],
#  'retrouve scorpion autre nouveauté inverse': [11124],
#  'retrouve bureau légendes matin': [234],
#  'retrouve effectivement série américaine assumé': [1360],
#  'retrouve souvent poche manteau fille': [25881],
#  'retrouve aussi brillante olivia': [16327],
#  'retrouve certains codes the wire': [29365],
#  'retrouve pouvoir réalisé simon': [14533],
#  'retrouve terrain syrie liban': [16904],
#  'retrouve netflix présent plus': [27567, 27568],
#  'retrouve parachuté cuisine sans conviction': [13923],
#  'retrouve autres shantel vansanten gang': [11496],
#  'retrouve mise scène': [10794],
#  'retrouve toujours @mediapart': [6228],
#  'retrouve vraie': [1027, 1031, 2660, 2670, 2725, 3152, 3288, 3439],
#  'retrouve niveau première': [13296],
#  'retrouve thème cœur': [27510],
#  'retrouve sphère familiale marie claire': [17479],
#  'retrouve': [0,
#   11,
#   25,
#   25,
#   37,
#   38,
#   119,
#   178,
#   186,
#   187,
#   211,
#   212,
#   223,
#   224,
#   225,
#   227,
#   230,
#   234,
#   395,
#   417,
#   448,
#   492,
#   492,
#   512,
#   512,
#   536,
#   620,
#   638,
#   638,
#   668,
#   880,
#   893,
#   899,
#   915,
#   916,
#   961,
#   1027,
#   1031,
#   1265,
#   1360,
#   1516,
#   1780,
#   1780,
#   1780,
#   1780,
#   1808,
#   2046,
#   2051,
#   2265,
#   2384,
#   2389,
#   2430,
#   2430,
#   2476,
#   2543,
#   2544,
#   2544,
#   2544,
#   2576,
#   2612,
#   2660,
#   2670,
#   2694,
#   2725,
#   2770,
#   2831,
#   2833,
#   2866,
#   2867,
#   2891,
#   2902,
#   2926,
#   3000,
#   3018,
#   3099,
#   3100,
#   3151,
#   3152,
#   3153,
#   3178,
#   3179,
#   3241,
#   3288,
#   3336,
#   3344,
#   3363,
#   3439,
#   3583,
#   3874,
#   3903,
#   4351,
#   4724,
#   4729,
#   4734,
#   4735,
#   4736,
#   4737,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4743,
#   4744,
#   4745,
#   4746,
#   5070,
#   5251,
#   5288,
#   5292,
#   5298,
#   5303,
#   5308,
#   5324,
#   5346,
#   5399,
#   5426,
#   5430,
#   5430,
#   5455,
#   5474,
#   5514,
#   5659,
#   5701,
#   5702,
#   5703,
#   5704,
#   5705,
#   5706,
#   5707,
#   5708,
#   5709,
#   5710,
#   5711,
#   5712,
#   5713,
#   5724,
#   5755,
#   5784,
#   5806,
#   5814,
#   5821,
#   5831,
#   5831,
#   5839,
#   5848,
#   5883,
#   5884,
#   5888,
#   5896,
#   5972,
#   5982,
#   5983,
#   5984,
#   5985,
#   5986,
#   5987,
#   5988,
#   5989,
#   5990,
#   5991,
#   5992,
#   5993,
#   5994,
#   6022,
#   6022,
#   6024,
#   6044,
#   6141,
#   6228,
#   6272,
#   6274,
#   6383,
#   6383,
#   6395,
#   6449,
#   6635,
#   6795,
#   6964,
#   7075,
#   7630,
#   7804,
#   7929,
#   7937,
#   7940,
#   7941,
#   7942,
#   7944,
#   7946,
#   8084,
#   8084,
#   8335,
#   8491,
#   8520,
#   8768,
#   8812,
#   8815,
#   8817,
#   8818,
#   8827,
#   8828,
#   8830,
#   8835,
#   8839,
#   8917,
#   8946,
#   8946,
#   8946,
#   8946,
#   8954,
#   8973,
#   9039,
#   9204,
#   9204,
#   9336,
#   9343,
#   9354,
#   9503,
#   9504,
#   9505,
#   9507,
#   9524,
#   9562,
#   9820,
#   9820,
#   9820,
#   9941,
#   9941,
#   10016,
#   10128,
#   10179,
#   10431,
#   10433,
#   10433,
#   10437,
#   10437,
#   10451,
#   10489,
#   10679,
#   10680,
#   10689,
#   10690,
#   10694,
#   10700,
#   10774,
#   10790,
#   10791,
#   10791,
#   10791,
#   10794,
#   10835,
#   10957,
#   11001,
#   11062,
#   11124,
#   11124,
#   11140,
#   11146,
#   11176,
#   11213,
#   11481,
#   11481,
#   11496,
#   11496,
#   11496,
#   11496,
#   11496,
#   11496,
#   11496,
#   11496,
#   11727,
#   11728,
#   11730,
#   11918,
#   12034,
#   12036,
#   12036,
#   12036,
#   12036,
#   12036,
#   12036,
#   12036,
#   12036,
#   12036,
#   12364,
#   12367,
#   12428,
#   12463,
#   12501,
#   12562,
#   12583,
#   12583,
#   12663,
#   12663,
#   12663,
#   12687,
#   12704,
#   12745,
#   12796,
#   12812,
#   12816,
#   12816,
#   12819,
#   12873,
#   12884,
#   12893,
#   12894,
#   12926,
#   12926,
#   12981,
#   12982,
#   12983,
#   12984,
#   12985,
#   12986,
#   12987,
#   12988,
#   12989,
#   12990,
#   12991,
#   12992,
#   12993,
#   12994,
#   12995,
#   12996,
#   12997,
#   12998,
#   13000,
#   13001,
#   13002,
#   13003,
#   13004,
#   13005,
#   13006,
#   13007,
#   13008,
#   13009,
#   13010,
#   13011,
#   13012,
#   13013,
#   13014,
#   13015,
#   13017,
#   13018,
#   13019,
#   13020,
#   13021,
#   13022,
#   13023,
#   13024,
#   13025,
#   13026,
#   13027,
#   13028,
#   13029,
#   13030,
#   13031,
#   13032,
#   13033,
#   13034,
#   13035,
#   13036,
#   13038,
#   13039,
#   13040,
#   13041,
#   13042,
#   13043,
#   13044,
#   13045,
#   13046,
#   13047,
#   13048,
#   13049,
#   13050,
#   13051,
#   13052,
#   13053,
#   13054,
#   13055,
#   13056,
#   13057,
#   13058,
#   13059,
#   13061,
#   13064,
#   13065,
#   13066,
#   13071,
#   13088,
#   13135,
#   13157,
#   13199,
#   13216,
#   13216,
#   13227,
#   13227,
#   13265,
#   13296,
#   13304,
#   13325,
#   13325,
#   13346,
#   13348,
#   13362,
#   13402,
#   13402,
#   13656,
#   13656,
#   13656,
#   13656,
#   13693,
#   13788,
#   13810,
#   13824,
#   13826,
#   13826,
#   13830,
#   13841,
#   13841,
#   13841,
#   13841,
#   13923,
#   13923,
#   13923,
#   13986,
#   13986,
#   13986,
#   14068,
#   14068,
#   14070,
#   14070,
#   14070,
#   14155,
#   14166,
#   14168,
#   14232,
#   14249,
#   14320,
#   14339,
#   14425,
#   14425,
#   14425,
#   14425,
#   14425,
#   14426,
#   14430,
#   14431,
#   14435,
#   14435,
#   14435,
#   14461,
#   14461,
#   14462,
#   14463,
#   14463,
#   14507,
#   14522,
#   14522,
#   14533,
#   14533,
#   14533,
#   14533,
#   14558,
#   14573,
#   14588,
#   14671,
#   14774,
#   15095,
#   15223,
#   15277,
#   15543,
#   15617,
#   15671,
#   16057,
#   16057,
#   16160,
#   16216,
#   16267,
#   16268,
#   16324,
#   16327,
#   16327,
#   16327,
#   16327,
#   16420,
#   16420,
#   16421,
#   16421,
#   16424,
#   16493,
#   16805,
#   16806,
#   16858,
#   16865,
#   16898,
#   16904,
#   16911,
#   16952,
#   16973,
#   16974,
#   17054,
#   17116,
#   17116,
#   17185,
#   17290,
#   17297,
#   17301,
#   17302,
#   17304,
#   17305,
#   17356,
#   17357,
#   17364,
#   17364,
#   17364,
#   17451,
#   17451,
#   17451,
#   17451,
#   17479,
#   17492,
#   17523,
#   17531,
#   17622,
#   17685,
#   17781,
#   17781,
#   17784,
#   17794,
#   18101,
#   18314,
#   19070,
#   19327,
#   19422,
#   19529,
#   19546,
#   19547,
#   19554,
#   19564,
#   19656,
#   19720,
#   19721,
#   19905,
#   20033,
#   20570,
#   20655,
#   20655,
#   20655,
#   20731,
#   20731,
#   20731,
#   20922,
#   20923,
#   20991,
#   21336,
#   21470,
#   21546,
#   21963,
#   22025,
#   22457,
#   22715,
#   23661,
#   23876,
#   23877,
#   24155,
#   24272,
#   25214,
#   25569,
#   25608,
#   25811,
#   25881,
#   26081,
#   26569,
#   26569,
#   26569,
#   26847,
#   26856,
#   26921,
#   26961,
#   27157,
#   27253,
#   27360,
#   27361,
#   27389,
#   27468,
#   27510,
#   27510,
#   27528,
#   27528,
#   27567,
#   27568,
#   27635,
#   27726,
#   27742,
#   27743,
#   27744,
#   27745,
#   27746,
#   27747,
#   27751,
#   27752,
#   27753,
#   27754,
#   27755,
#   27756,
#   27757,
#   27758,
#   27759,
#   27764,
#   27775,
#   27776,
#   27778,
#   27781,
#   27782,
#   27783,
#   27784,
#   27845,
#   27854,
#   28091,
#   28187,
#   28334,
#   28334,
#   28334,
#   28368,
#   28679,
#   28679,
#   28715,
#   28890,
#   28890,
#   28890,
#   28910,
#   29164,
#   29165,
#   29178,
#   29180,
#   29188,
#   29198,
#   29198,
#   29208,
#   29213,
#   29238,
#   29263,
#   29267,
#   29269,
#   29303,
#   29345,
#   29351,
#   29363,
#   29365,
#   29365,
#   29366,
#   29368,
#   29373,
#   29377,
#   29382,
#   29383,
#   29384,
#   29389],
#  'retrouve léa drucker': [19529],
#  'retrouve shameless': [12036],
#  'retrouve prune pose questions paul': [8768, 11176, 27764],
#  'retrouve peu john': [5831],
#  'retrouve moment': [178],
#  'retrouve femme planches': [3151,
#   3153,
#   3178,
#   3344,
#   3363,
#   3583,
#   3903,
#   4734,
#   4735,
#   4736,
#   4737,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4743,
#   4744,
#   4745,
#   4746,
#   5251,
#   5292,
#   5303,
#   5399,
#   5455,
#   5474,
#   5514,
#   5701,
#   5702,
#   5703,
#   5704,
#   5705,
#   5706,
#   5707,
#   5708,
#   5709,
#   5710,
#   5711,
#   5712,
#   5713,
#   5724,
#   5755,
#   5784,
#   5814,
#   5821,
#   5839,
#   5848,
#   5883,
#   5884,
#   5888,
#   5896,
#   5972,
#   5982,
#   5983,
#   5984,
#   5985,
#   5986,
#   5987,
#   5988,
#   5989,
#   5990,
#   5991,
#   5992,
#   5993,
#   5994,
#   6044],
#  'retrouve table': [19327],
#  'retrouve téhéran entourage famille liée': [17356],
#  'retrouve idole roy': [10179],
#  'retrouve quarante ans plus': [17116],
#  'retrouve équipe bureau légendes quelques': [17185, 17297],
#  'retrouve donc malotru': [16420, 16421, 16424],
#  'retrouve the affair': [12036],
#  'retrouve thématiques familières': [8491],
#  'retrouve hugh jackman rila fukushima': [20922, 20923],
#  'retrouve plaisir autre genre': [8917, 8954, 29303],
#  'retrouve embarqué ennuis police': [14435],
#  'retrouve bien ancrées vie réelle': [25214],
#  'retrouve plaisir autre genre brendan': [8917, 8954, 29303],
#  'retrouve notamment megan': [13216, 13227, 13402],
#  'retrouve corps': [26569],
#  'retrouve ncis nouvelle': [11140],
#  'retrouve long épisodes': [13841],
#  'retrouve confrontée monde rural habitudes': [7075],
#  'retrouve the affair remporté': [12036],
#  'retrouve paga 2015': [5806],
#  'retrouve line renaud nathalie': [14320],
#  'retrouve souvent poche': [25881],
#  'retrouve boucle histoire': [16267, 16268, 17794],
#  'retrouve aussi brillante olivia coleman': [16327],
#  'retrouve force': [13986],
#  'retrouve ultime saison mentalist grey': [11],
#  'retrouve assassinée chambre hôtel': [16327],
#  'retrouve aussi grand': [13088],
#  'retrouve face deux': [1516],
#  'retrouve plongé arène': [14461, 14461, 14463, 14463],
#  'retrouve comédien': [26961],
#  'retrouve archétypes champion': [6395],
#  'retrouve histoire littérature genre': [14070],
#  'retrouve également camille cottin connasse': [16911],
#  'retrouve unbreakable kimmy schmidt': [12036],
#  'retrouve réfugier laborieusement derrière certaines': [14425],
#  'retrouve famille reprend marques mission': [16327],
#  'retrouve nouveauté wgn america manhattan': [12036],
#  'retrouve menus présente bien': [448],
#  'retrouve bord': [28334],
#  'retrouve compère that': [12463],
#  'retrouve place trop bureau': [915, 916],
#  'retrouve blooklyn comment': [12816],
#  'retrouve fille danger choses': [8946],
#  'retrouve viseur bdl': [29269],
#  'retrouve amiel devenu très': [10791],
#  'retrouve dawgz': [7630],
#  'retrouve embouteillages commencé juste perturbant': [15671],
#  'retrouve donc plein années': [11496],
#  'retrouve slogan charlie': [37, 38],
#  'retrouve grégory': [14573],
#  'retrouve ensuite mediapart #lbdl pousse': [6272, 6274],
#  'retrouve nadia impliquée négociations': [25569],
#  'retrouve histoire clans fois': [8335],
#  'retrouve séries deutschland vie': [2891, 3000, 14426],
#  'retrouve sept': [12036],
#  'retrouve léa drucker balmès florence': [19529],
#  'retrouve encore fois marie jeanne': [20655, 20731],
#  'retrouve blooklyn': [12816],
#  'retrouve plus grands espions service': [11001],
#  'retrouve légende saison sait saison': [16973, 16974],
#  'retrouve françois': [11496],
#  'retrouve femme planches 04france': [4734,
#   4735,
#   4736,
#   4737,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4743,
#   4744,
#   4745,
#   4746,
#   5251,
#   5292,
#   5303,
#   5399,
#   5455,
#   5474,
#   5514,
#   5701,
#   5702,
#   5703,
#   5704,
#   5705,
#   5706,
#   5707,
#   5708,
#   5709,
#   5710,
#   5711,
#   5712,
#   5713,
#   5724,
#   5755,
#   5784,
#   5814,
#   5821,
#   5839,
#   5848,
#   5883,
#   5884,
#   5888,
#   5896,
#   5972,
#   5982,
#   5983,
#   5984,
#   5985,
#   5986,
#   5987,
#   5988,
#   5989,
#   5990,
#   5991,
#   5992,
#   5993,
#   5994,
#   6044],
#  'retrouve hippocampus studio baguette bureau': [9039],
#  'retrouve grégory montel révélé air': [14573],
#  'retrouve nadia impliquée': [25569],
#  'retrouve terrain prédilection histoires espions': [3018, 3099, 3100],
#  'retrouve mathilde seigner mère': [17364],
#  'retrouve très vite limitée peu': [15223],
#  'retrouve aussi ecoutes nsa': [19546, 19547, 19554, 19564, 21470],
#  'retrouve dernier': [25],
#  'retrouve composer recoller': [12501],
#  'retrouve thématiques': [8491],
#  'retrouve donc notamment': [16806, 16898],
#  'retrouve mise scène opéras pièces': [10794],
#  'retrouve beaucoup scènes salle': [20655, 20731],
#  'retrouve bien': [14435, 17301, 17302, 17357, 25214],
#  'retrouve thème cœur première série': [27510],
#  'retrouve doté vitesse': [13841],
#  'retrouve effectivement': [1360],
#  'retrouve derrière': [13824],
#  'retrouve application': [29389],
#  'retrouve mathieu kassovitz jean pierre': [3874],
#  'retrouve espion guillaume debailly': [15617],
#  'retrouve peu john carré peut': [5831],
#  'retrouve allant série': [29178, 29180, 29365],
#  'retrouve rapidement forcé': [6022],
#  'retrouve allant série originale': [29178, 29180, 29365],
#  'retrouve mis examen': [20991],
#  'retrouve confrontée frontière': [11146],
#  'retrouve fantastique': [13216, 13227, 13402],
#  'retrouve six': [9820],
#  'retrouve toujours @mediapart image dgse': [6228],
#  'retrouve finalement petit': [13923],
#  'retrouve tenir': [1780],
#  'retrouve prochain fond cœur': [14522],
#  'retrouve thèmes': [1780],
#  'retrouve première marche': [9820],
#  'retrouve propulsée 2012 aventure revenants': [536],
#  'retrouve piégé': [27157],
#  'retrouve vite plongé nouvelles aventures': [11062],
#  'retrouve josh holloway': [14533],
#  'retrouve 2001': [8520],
#  'retrouve confondu rôle entièrement fabriqué': [29366,
#   29368,
#   29377,
#   29382,
#   29383],
#  'retrouve oréal danone bonduelle auchan': [27360, 27361, 27389, 27468],
#  'retrouve nouveauté wgn': [12036],
#  'retrouve marina loiseau sara': [19070, 19422, 19720],
#  'retrouve embouteillages commencé juste': [15671],
#  'retrouve vraie vie paris': [1027, 1031, 2660, 2670, 2725, 3152, 3288, 3439],
#  'retrouve donc plein': [11496],
#  'retrouve expliquer non vais genre': [13693],
#  'retrouve complice': [12893],
#  'retrouve troubles': [29165],
#  'retrouve écran': [10790, 12704],
#  'retrouve hôpital coma léo sans': [28334],
#  'retrouve tf1 esprits': [26847],
#  'retrouve aime cinéma français côté': [7804],
#  'retrouve histoire': [8335, 14070],
#  'retrouve bord gouffre': [28334],
#  'retrouve marilou sarah mehdi six': [14774],
#  'retrouve coeur sombre machination tenter': [3241],
#  'retrouve nombreuses': [16865],
#  'retrouve parmi elles spotless': [211, 212],
#  'retrouve talent patriotes échec': [14588],
#  'retrouve sept épisodes finaux mad': [12036],
#  'retrouve marc andré': [187],
#  'retrouve nadia': [25569],
#  'retrouve ainsi talent': [27726],
#  'retrouve gillian anderson incarner fox': [14671],
#  'retrouve @mediapart': [6024, 12364, 12367, 12884],
#  'retrouve place trop bureau légendes': [915, 916],
#  'retrouve mathieu kassovitz jean': [3874],
#  'retrouve sans': [1265, 29208],
#  'retrouve complice michel': [12893],
#  'retrouve toujours @mediapart image': [6228],
#  'retrouve fille collègues bureau légendes': [2831, 2833],
#  'retrouve plaisir ambiance également beaucoup': [11496],
#  'retrouve dénominateurs communs the': [8946],
#  'retrouve chez': [12981],
#  'retrouve infiltration': [13656, 13656],
#  'retrouve tommy convaincre': [26569],
#  'retrouve suivi sens danger partout': [8946],
#  'retrouve thème cœur première': [27510],
#  'retrouve quarante ans plus tard': [17116],
#  'retrouve derrière arte tmc': [13824],
#  'retrouve assassinée chambre': [16327],
#  'retrouve notamment felicity huffman': [25],
#  'retrouve quotidien parisien': [5070],
#  'retrouve mediapart réplique culte #lebureaudeslegendes': [9562],
#  'retrouve chronique': [15277, 17364],
#  'retrouve effet réalisation': [0],
#  'retrouve importance': [28679],
#  'retrouve hôpital wayward': [14507],
#  'retrouve 2001 michael': [8520],
#  'retrouve premier ministre enlevé': [6383],
#  'retrouve pays origine': [492, 512],
#  'retrouve iran': [29345, 29351],
#  'retrouve pays autre': [12562],
#  'retrouve envoyée': [17523, 17531],
#  'retrouve hôpital': [14507, 28334],
#  'retrouve grégory montel': [14573],
#  'retrouve sphère familiale marie': [17479],
#  'retrouve donc jane fonda': [11496],
#  'retrouve casting série italienne marco': [28910],
#  'retrouve certains codes the': [29365],
#  'retrouve devant': [5298, 16327],
#  'retrouve noms irène jacob double': [15095],
#  'retrouve viseur mystérieux groupe vocation': [17451],
#  'retrouve parachuté': [13923],
#  'retrouve confondu rôle': [29366, 29368, 29377, 29382, 29383, 29384],
#  'retrouve rupture chaises incident diplomatique': [1780],
#  'retrouve premier ministre': [6383],
#  'retrouve scénaristes wood 1994 scott': [417],
#  'retrouve alexandra lamy certes': [13986],
#  'retrouve quand malice coin': [11496],
#  'retrouve nathalieandref2 semaine prochaine': [22457],
#  'retrouve seul': [13325, 13325],
#  'retrouve énormément romans john': [8946],
#  'retrouve chroniqueurs patrice carmouze': [16216],
#  'retrouve immédiatement médiapart': [6795],
#  'retrouve alexandra lamy': [13986],
#  'retrouve face reconnaît plus': [10679, 10680],
#  'retrouve également photo ancien': [13923],
#  'retrouve ensuite mediapart mag gilles': [10433],
#  'retrouve archétypes': [6395],
#  'retrouve propulsée': [536],
#  'retrouve ultime saison mentalist': [11],
#  'retrouve donc bureau légendes quatre': [16858],
#  'retrouve hugh': [20922, 20923],
#  'retrouve quasi totalité': [12812, 29267],
#  'retrouve enfin mathieu kassovitz top': [14462],
#  'retrouve aussi quelques séries': [28890],
#  'retrouve françois david': [11496],
#  'retrouve quelques partenaires': [12926],
#  'retrouve thèmes spécialiste français': [1780],
#  'retrouve tommy convaincre quand monter': [26569],
#  'retrouve suits': [13362],
#  'retrouve donc derrière cela principalement': [13656],
#  'retrouve soleil dedans': [2389, 2694],
#  'retrouve troubles géo politiques': [29165],
#  'retrouve soleil': [2389, 2694],
#  'retrouve enfin plupart': [20655, 20731],
#  'retrouve assassinée': [16327],
#  'retrouve casting premium': [620],
#  'retrouve rapidement forcé collaborer': [6022],
#  'retrouve famille reprend': [16327],
#  'retrouve flop stalker': [12894],
#  'retrouve présentateur heures': [17451],
#  'retrouve paris aime carlos interprète': [29373],
#  'retrouve table premier ministre': [19327],
#  'retrouve quand': [11496],
#  'retrouve chaque show plaisir': [27742,
#   27743,
#   27744,
#   27745,
#   27746,
#   27747,
#   27751,
#   27752,
#   27753,
#   27754,
#   27755,
#   27756,
#   27757,
#   27758,
#   27759,
#   27775,
#   27776,
#   27778,
#   27781,
#   27782,
#   27783,
#   27784,
#   28187],
#  'retrouve hôpital wayward pines apre': [14507],
#  'retrouve canal': [2544],
#  'retrouve certains': [23876, 23877, 29365],
#  'retrouve marc andré grondin': [187],
#  'retrouve hôpital coma': [28334],
#  'retrouve silvio': [12663],
#  'retrouve scénariste problèmes rythme évidents': [28890],
#  'retrouve alors embarqué histoire politique': [12583],
#  'retrouve ici hôpital ambiance': [12583],
#  'retrouve effectivement série': [1360],
#  'retrouve quelques partenaires jeu films': [12926],
#  'retrouve fibre film patriotes': [3179, 5430, 5430],
#  'retrouve viseur bdl parce entrées': [29269],
#  'retrouve épisodes deviousmaids peux écrire': [23661],
#  'retrouve françois david jonathan cardonell': [11496],
#  'retrouve mise scène opéras': [10794],
#  'retrouve donc notamment cinéma canal': [16806, 16898],
#  'retrouve confondu rôle entièrement': [29366,
#   29368,
#   29377,
#   29382,
#   29383,
#   29384],
#  'retrouve évidemment jon hamm elisabeth': [119],
#  'retrouve vite désamorcé enfin': [12687],
#  'retrouve @mediapart agent #fsb dgse': [12884],
#  'retrouve coeur': [3241, 22025],
#  'retrouve habillé plage': [14232],
#  'retrouve notamment': [25, 13216, 13227, 13402, 27510, 27528],
#  'retrouve plus grands': [11001],
#  'retrouve affaire': [19721],
#  'retrouve bikini': [2046, 2051],
#  'retrouve très vite': [15223],
#  'retrouve bien sûr malotru impeccable': [17301, 17302, 17357],
#  'retrouve blida dès lundi républicain': [2770],
#  'retrouve silvio dante pays': [12663],
#  'retrouve peau': [10016],
#  'retrouve vite désamorcé enfin soulignera': [12687],
#  'retrouve charge petite fille sterling': [29198],
#  'retrouve situation compliquée': [20033],
#  'retrouve notamment marina envoyée': [27510, 27528],
#  'retrouve femme planches 04france diffuser': [4734,
#   4735,
#   4736,
#   4737,
#   4738,
#   4739,
#   4740,
#   4741,
#   4742,
#   4743,
#   4744,
#   4745,
#   4746,
#   5251,
#   5292,
#   5303,
#   5399,
#   5455,
#   5474,
#   5514,
#   5701,
#   5702,
#   5703,
#   5704,
#   5705,
#   5706,
#   5707,
#   5708,
#   5709,
#   5710,
#   5711,
#   5712,
#   5713,
#   5724,
#   5755,
#   5784,
#   5814,
#   5821,
#   5839,
#   5848,
#   5883,
#   5884,
#   5888,
#   5896,
#   5972,
#   5982,
#   5983,
#   5984,
#   5985,
#   5986,
#   5987,
#   5988,
#   5989,
#   5990,
#   5991,
#   5992,
#   5993,
#   5994,
#   6044],
#  'retrouve chronique adolescente': [15277],
#  'retrouve énormément': [8946],
#  'retrouve faut': [10957, 15543],
#  'retrouve plaisir': [8917, 8954, 11496, 29303],
#  'retrouve hippocampus studio': [9039],
#  'retrouve épisodes': [23661],
#  ...}

# %% [markdown]
# ### Additional information: medias and time activity

# %%
word_selected = "légendes"

# %%
word_selected
# Out:
# 'légendes'

# %%
medias = text_data.loc[dic_of_ngrams[word_selected]].platform.value_counts()

# %%
medias.to_dict()
# Out:
# {'Blog': 753,
#  'Comment': 36,
#  'Dailymotion': 35,
#  'Facebook': 465,
#  'Forum': 223,
#  'Gplus': 2,
#  'Instagram': 44,
#  'Media': 2428,
#  'Twitter': 7329,
#  'Website': 3671,
#  'Youtube': 87}

# %%
timeseries = text_data.loc[dic_of_ngrams[word_selected]].date.sort_values()
timeseries = timeseries.groupby(timeseries.dt.strftime('%Y-%m-%d')).size()
#df_time = timeseries.to_frame()
#df_time['Week/Year']=df_time.date.apply(lambda x: "%d/%d" % (x.week, x.year))
#timeseries = timeseries.apply(lambda x: "%d/%d/%d" % (x.year,x.month,x.day))

# %%
import matplotlib.pyplot as plt

# %%
timeseries.plot()
plt.show()

# %%
text_data.loc[dic_of_ngrams[word_selected]].date.hist(bins=50)
plt.show()

# %% [markdown]
# ### Creation of a dict of information for each ngram

# %%
def get_ngram_infos(dic_of_ngrams,text_data):
    """ create a new dic of ngrams containing information about 
        * nb of occurences of the ngram
        * medias where the ngram appear
        * a time series of ngram appearance
        input a dic with ngrams as keys and list of indices where the ngram appear as value
    """
    info_dic_of_ngrams = {}
    for k in dic_of_ngrams.keys():
        list_k = dic_of_ngrams[k]
        info_dic_k = {}
        info_dic_k['nb_occur'] = len(list_k)
        info_dic_k['medias'] = text_data.loc[list_k].platform.value_counts().to_dict()
        timeseries = text_data.loc[list_k].date.sort_values()
        start_time = timeseries.iloc[0]
        timeseries = timeseries.groupby(timeseries.dt.strftime('%d-%m-%Y')).size()
        info_dic_k['timeseries'] = timeseries.to_dict()
        info_dic_k['start_time'] = start_time.strftime('%d-%m-%Y')
        info_dic_of_ngrams[k]=info_dic_k
    return info_dic_of_ngrams

# %%
info_dic_of_ngrams = get_ngram_infos(dic_of_ngrams,text_data)

# %%
info_dic_of_ngrams[word_selected]['nb_occur']
# Out:
# 15073

# %%
mediastmp = info_dic_of_ngrams[word_selected]['medias']
mediastmp
# Out:
# {'Blog': 753,
#  'Comment': 36,
#  'Dailymotion': 35,
#  'Facebook': 465,
#  'Forum': 223,
#  'Gplus': 2,
#  'Instagram': 44,
#  'Media': 2428,
#  'Twitter': 7329,
#  'Website': 3671,
#  'Youtube': 87}

# %%
# find the media with the maximal value
main_media = max(mediastmp, key=lambda key: mediastmp[key])

# %%
main_media,mediastmp[main_media]
# Out:
# ('Twitter', 7329)

# %%
info_dic_of_ngrams[word_selected]['start_time']
# Out:
# '01-01-2015'

# %% [markdown]
# ### Creating the graph

# %%
G,root_id = mtg.createTreeGraph_fromdic(info_dic_of_ngrams,candidat_word,threshold=35)
# Out:
# Create the graph and add the root node 'légendes'.
# Add children nodes from the n-grams dataset.

# %%
G.size()
# Out:
# 150

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
nx.draw_spring(G)
plt.show()

# %%
print(G.size())
#print(G.in_degree())
# Out:
# 224

# %% [markdown]
# ### Properties of the edges

# %%
## OPTIONAL

## Extracting the edge information
#sum_weight = 0
#n_edges = 0
#for u,v,a in G.edges(data=True):
#    sum_weight+=a['weight']
#    n_edges+=1
#average_weight = sum_weight*1.0/n_edges

## Node properties: degree and centrality
#degreeDic = G.degree(weight='weight')
#nx.set_node_attributes(G,'degree',degreeDic)
#bcDic = nx.betweenness_centrality(G)
#nx.set_node_attributes(G,'bCentrality',bcDic)

# %% [markdown]
# ### Saving the graph

# %%
# Write the graph to a json file
json_filename = "treegraph"+series_name+".json"
from networkx.readwrite import json_graph
datag = json_graph.tree_data(G,root=root_id)
import json
s = json.dumps(datag)
#datag['links'] = [
#        {
#            'source': datag['nodes'][link['source']]['id'],
#            'target': datag['nodes'][link['target']]['id']
#        }
#        for link in datag['links']]
s = json.dumps(datag)
with open("./viz/"+json_filename, "w") as f:
    f.write(s)

# %% [markdown]
# ### Open a web page for visualization

# %%
# run a websever in the folder where the json file has been saved
# python3 -m http.server --bind 127.0.0.1 8008

import webbrowser
url = 'http://localhost:8008/treegraphmeme.html'+'?'+'file='+json_filename
#webbrowser.open_new_tab(url)
webbrowser.open_new(url)
# Out:
# True

# %%
G.edges(data='weight')

# %% [markdown]
# Deprecated

# %%
print('Add children nodes in the {}-grams dataset.'.format(n_grams))
ngram_df = list_of_ngram_df_merged[n_grams-1]
for idx,row in ngram_df.iterrows():
    word_list = row.ngram.split()
    #print(row.ngram)
    for idx,word in enumerate(word_list):
        if idx == 0:
            grand_parent = ''
        else:
            parent_word = word_list[idx-1]
            word_id = word+parent_word+str(idx)
            if G.has_node(word_id):
                G.node[word_id]['occur'] += 1
                #nx.set_node_attributes(G, 'occur', G.node[word_id]['occur']+1)
            else:
                G.add_node(word_id,name=word, occur=1)
            parent_id = parent_word+grand_parent+str(idx-1)
            if G.has_edge(parent_id,word_id):
                # we added this one before, just increase the weight by one
                G[parent_id][word_id]['weight'] += 1
            else:
                # new edge. add with weight=1
                G.add_edge(parent_id, word_id, weight=1)
            grand_parent = parent_word
            if idx == len(word_list)-1:
                G.node[word_id]['occur'] = row.nb_occur

# %%
clusterDic

# %%
neighbour_data1,df_texts_subset1 = top_neighbours('peau',df_texts_list,direction='forward',top_n=10)
print(neighbour_data1.head(1))
neighbour_data2,df_texts_subset2 = top_neighbours(neighbour_data1.head(1).word[0],df_texts_subset1,direction='forward',top_n=10)
print(neighbour_data2.head(1))
neighbour_data3,df_texts_subset3 = top_neighbours(neighbour_data2.head(1).word[0],df_texts_subset2,direction='forward',top_n=10)

#neighbour_data2,texts_subset2 = top_neighbours(neighbour_data.head(1).word[0],texts_subset1,direction='forward',top_n=10)

# %%
df_texts_subset2.text.loc[11060]

# %%
neighbour_data1,texts_subset1 = top_neighbours('égalité',text_data.filtered_text,direction='forward',top_n=10)
print(neighbour_data1.head(1))
neighbour_data2,texts_subset2 = top_neighbours(neighbour_data1.head(1).word[0],texts_subset1,direction='forward',top_n=10)
print(neighbour_data2.head(1))
neighbour_data3,texts_subset3 = top_neighbours(neighbour_data2.head(1).word[0],texts_subset2,direction='forward',top_n=10)

# %%
texts_subset3
