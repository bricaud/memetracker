# %% [markdown]
# ## Stats sur les ngrams

# %%
import pandas as pd

# %%
df = pd.read_csv('./collaboration/6-CORTEXT-MARSEILLE-26756/4-MARSEILLE-top1000-list-terms.csv',sep=None)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df
# Out:
#                                  entity  frequency  \
# 0                          Marseillais       16199
# 1                              Netflix        6061
# 2                       serie Marseille       5047
# 3                         DANS LA SERIE       3017
# 4                             seul truc       2912
# 5                          MARSEILLE DE       1914
# 6                           DE LA SÉRIE       1682
# 7                        série Netflix        1373
# 8                      Gérard Depardieu       1202
# 9            série Marseille de Netflix        714
# 10           série française de Netflix        667
# 11              Pour la série Marseille        539
# 12                       Benoît Magimel        538
# 13          série d'agressions racistes        494
# 14      agressions racistes à Marseille        416
# 15              série originale Netflix        391
# 16                      série française        385
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
#plt.hist(df[df['frequency']<700]['frequency'],bins=200)
plt.plot(df['frequency'])
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
len(df[df['frequency']<100])
# Out:
# 798

# %%
len(df[df['frequency']>100])
# Out:
# 48

# %%
len(df[ df['frequency']>1000])
# Out:
# 9
